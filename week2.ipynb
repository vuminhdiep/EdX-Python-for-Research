# %%
import numpy as np

# %%
zero_vector = np.zeros(5)

# %%
print(zero_vector)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,4,9,16])

# %%
plt.plot([0,1,2],[0,1,4],"rd-")
